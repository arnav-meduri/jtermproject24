# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/My_City_Data.csv")
data
# Out:
#          CASE # DATE  OF OCCURRENCE  PRIMARY DESCRIPTION  \
# 0      HX332780              7/5/14        OTHER OFFENSE
# 1      HX332854              7/5/14        OTHER OFFENSE
# 2      HX332743              7/5/14      CRIMINAL DAMAGE
# 3      HX332735              7/5/14                THEFT
# 4      HX332740              7/5/14    CRIMINAL TRESPASS
# ...         ...                 ...                  ...
# 12697       NaN                 NaN                  NaN
# 12698       NaN                 NaN                  NaN
# 12699       NaN                 NaN                  NaN
# 12700       NaN                 NaN                  NaN
# 12701       NaN                 NaN                  NaN
#
#          SECONDARY DESCRIPTION            LOCATION DESCRIPTION ARREST  \
# 0          PROBATION VIOLATION  PARKING LOT/GARAGE(NON.RESID.)      Y
# 1      HARASSMENT BY TELEPHONE                       APARTMENT      N
# ...

# %%
data_arr = data[data["ARREST"] == "Y"]
data_arr
num_arr = len(data_arr)

# %%
data_narr = data[data["ARREST"] == "N"]
num_narr = len(data_narr)

# %%
num_total = len(data)

# %%
per_arr = (num_arr/num_total)*100
per_narr = (num_narr/num_total)*100

# %%
per_arr
# Out:
# 25.35821130530625

# %%
per_narr
# Out:
# 62.517713745866786

# %%
arrest_counts = data['ARREST'].value_counts()

domestic_counts = data['DOMESTIC'].value_counts()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

axes[0].bar(arrest_counts.index, arrest_counts.values, color=['blue', 'blue'])
axes[0].set_title('Number of Arrested vs Non-Arrested')
axes[0].set_xlabel('Arrested')
axes[0].set_ylabel('Number of Cases')

axes[1].bar(domestic_counts.index, domestic_counts.values, color=['red', 'red'])
axes[1].set_title('Number of Domestic vs Non-Domestic Cases')
axes[1].set_xlabel('Domestic')
axes[1].set_ylabel('Number of Cases')

# Displaying the plots
plt.tight_layout()
plt.show()

# %%
# Correcting the column name for 'PRIMARY DESCRIPTION' (removing leading space)
crime_counts = data[' PRIMARY DESCRIPTION'].value_counts()

# Sorting the crimes by frequency
sorted_crime_counts = crime_counts.sort_values(ascending=False)

# Creating the bar plot
plt.figure(figsize=(10, 8))
sns.barplot(x=sorted_crime_counts.values, y=sorted_crime_counts.index, palette="vlag")

plt.title('Number of Each Type of Crime', fontsize=16)
plt.xlabel('Number of Cases', fontsize=12)
plt.ylabel('Type of Crime', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Displaying the plot
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
